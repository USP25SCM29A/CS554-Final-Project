# %% [markdown]
# #### Exploratory data analysis

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from statsmodels) (2.2.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (2.2.4)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing the required libraries
import pandas as pd # Dataframe operations 
import numpy as np #mathematical operations
import matplotlib.pyplot as plt #graphs
import seaborn as sns #graphs
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
df=pd.read_csv('data.csv')# reading the dataset using pandas

# %%
df.head()#Displaying the top 5 data values
# Out:
#     timestamp     open    close     high      low  volume
# 0  1569225600  9930.13  9930.13  9930.13  9930.13   0.001
# 1  1569229200      NaN      NaN      NaN      NaN   0.000
# 2  1569232800      NaN      NaN      NaN      NaN   0.000
# 3  1569236400      NaN      NaN      NaN      NaN   0.000
# 4  1569240000      NaN      NaN      NaN      NaN   0.000

# %%
df.tail()#Displaying the lower 5 data values
# Out:
#         timestamp      open     close      high       low   volume
# 40550  1715205600  61480.33  61266.23  61558.80  61134.05  1.68652
# 40551  1715209200  61257.18  61193.08  61292.43  60909.72  1.99517
# 40552  1715212800  61162.31  61467.90  61502.00  61137.33  7.75708
# 40553  1715216400  61412.17  61563.08  61563.09  61412.17  0.69730
# 40554  1715220000  61563.26  61550.15  61563.29  61507.37  0.01823

# %%
df.info() #Basic info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40555 entries, 0 to 40554
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  40555 non-null  int64
#  1   open       40478 non-null  float64
#  2   close      40478 non-null  float64
#  3   high       40478 non-null  float64
#  4   low        40478 non-null  float64
#  5   volume     40555 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 1.9 MB

# %%
df.describe#Description of the dataset
# Out:
# <bound method NDFrame.describe of         timestamp      open     close      high       low   volume
# 0      1569225600   9930.13   9930.13   9930.13   9930.13  0.00100
# 1      1569229200       NaN       NaN       NaN       NaN  0.00000
# 2      1569232800       NaN       NaN       NaN       NaN  0.00000
# 3      1569236400       NaN       NaN       NaN       NaN  0.00000
# 4      1569240000       NaN       NaN       NaN       NaN  0.00000
# ...           ...       ...       ...       ...       ...      ...
# 40550  1715205600  61480.33  61266.23  61558.80  61134.05  1.68652
# 40551  1715209200  61257.18  61193.08  61292.43  60909.72  1.99517
# 40552  1715212800  61162.31  61467.90  61502.00  61137.33  7.75708
# 40553  1715216400  61412.17  61563.08  61563.09  61412.17  0.69730
# 40554  1715220000  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 6 columns]>

# %%
df.duplicated().sum()#Numebr of duplicated values in the dataset
# Out:
# np.int64(0)

# %%
df.isnull() #Checking for any null values in the dataset
# Out:
#        timestamp   open  close   high    low  volume
# 0          False  False  False  False  False   False
# 1          False   True   True   True   True   False
# 2          False   True   True   True   True   False
# 3          False   True   True   True   True   False
# 4          False   True   True   True   True   False
# ...          ...    ...    ...    ...    ...     ...
# 40550      False  False  False  False  False   False
# 40551      False  False  False  False  False   False
# 40552      False  False  False  False  False   False
# 40553      False  False  False  False  False   False
# 40554      False  False  False  False  False   False
#
# [40555 rows x 6 columns]

# %%
df.isnull().sum()#Checking for the number of null values in the dataset
# Out:
# timestamp     0
# open         77
# close        77
# high         77
# low          77
# volume        0
# dtype: int64

# %%
df.columns #Columns present in the dataset
# Out:
# Index(['timestamp', 'open', 'close', 'high', 'low', 'volume'], dtype='object')

# %%
df.shape #(number of rows, number of columns)
# Out:
# (40555, 6)

# %%
df.head() #displaying top 5 values
# Out:
#     timestamp     open    close     high      low  volume
# 0  1569225600  9930.13  9930.13  9930.13  9930.13   0.001
# 1  1569229200      NaN      NaN      NaN      NaN   0.000
# 2  1569232800      NaN      NaN      NaN      NaN   0.000
# 3  1569236400      NaN      NaN      NaN      NaN   0.000
# 4  1569240000      NaN      NaN      NaN      NaN   0.000

# %% [markdown]
# #### It was observed that the Datatype of DATE column is object, so let us convert it into datetime.

# %%
import pandas as pd

# 1) Convert your timestamp
# If it’s Unix epoch seconds:
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
# If it’s strings in YYYY‑MM‑DD:
# df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d')

# 2) Make it the index (so ffill respects the time order)
df.set_index('timestamp', inplace=True)

# 3) Forward‑fill missing values in all columns
df.fillna(method='ffill', inplace=True)

# (Optional) If you only want to fill price columns:
# price_cols = ['OPEN','HIGH','LOW','CLOSE']
# df[price_cols] = df[price_cols].fillna(method='ffill')

print(df.head())
# Out:
#                         open    close     high      low  volume
# timestamp
# 2019-09-23 08:00:00  9930.13  9930.13  9930.13  9930.13   0.001
# 2019-09-23 09:00:00  9930.13  9930.13  9930.13  9930.13   0.000
# 2019-09-23 10:00:00  9930.13  9930.13  9930.13  9930.13   0.000
# 2019-09-23 11:00:00  9930.13  9930.13  9930.13  9930.13   0.000
# 2019-09-23 12:00:00  9930.13  9930.13  9930.13  9930.13   0.000
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/3925992639.py:13: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.info()# successfully converted the column to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 40555 entries, 2019-09-23 08:00:00 to 2024-05-09 02:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    40555 non-null  float64
#  1   close   40555 non-null  float64
#  2   high    40555 non-null  float64
#  3   low     40555 non-null  float64
#  4   volume  40555 non-null  float64
# dtypes: float64(5)
# memory usage: 1.9 MB

# %%
df #8857 rows × 7 columns in our dataset
# Out:
#                          open     close      high       low   volume
# timestamp
# 2019-09-23 08:00:00   9930.13   9930.13   9930.13   9930.13  0.00100
# 2019-09-23 09:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 10:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 11:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 12:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# ...                       ...       ...       ...       ...      ...
# 2024-05-08 22:00:00  61480.33  61266.23  61558.80  61134.05  1.68652
# 2024-05-08 23:00:00  61257.18  61193.08  61292.43  60909.72  1.99517
# 2024-05-09 00:00:00  61162.31  61467.90  61502.00  61137.33  7.75708
# 2024-05-09 01:00:00  61412.17  61563.08  61563.09  61412.17  0.69730
# 2024-05-09 02:00:00  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 5 columns]

# %%
#plotting the feature values 
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        plt.plot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %%
df
# Out:
#                          open     close      high       low   volume
# timestamp
# 2019-09-23 08:00:00   9930.13   9930.13   9930.13   9930.13  0.00100
# 2019-09-23 09:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 10:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 11:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 12:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# ...                       ...       ...       ...       ...      ...
# 2024-05-08 22:00:00  61480.33  61266.23  61558.80  61134.05  1.68652
# 2024-05-08 23:00:00  61257.18  61193.08  61292.43  60909.72  1.99517
# 2024-05-09 00:00:00  61162.31  61467.90  61502.00  61137.33  7.75708
# 2024-05-09 01:00:00  61412.17  61563.08  61563.09  61412.17  0.69730
# 2024-05-09 02:00:00  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 5 columns]

# %%
#Plotting the distribution plots for all the features
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/2315975778.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/2315975778.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/2315975778.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/2315975778.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/2315975778.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])

# %%
sns.pairplot(data=df) # relation between each and every variable present in Pandas DataFrame.

# %% [markdown]
# ### Insights from the plot above:-
# - Above plot shows pairwise relationships in a dataset.
# - Most of the plots are showing linear relationship while others are not showing any specific relationship

# %%
sns.heatmap(df.corr(),annot=True,cmap = "YlGnBu") #Graphical representation of data using colors to visualize the value of the matrix.
# Out:
# <Axes: >

# %% [markdown]
# #### Let us check for any outliers

# %%
#plotting boxplots for all the features
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Vertical visualization of the boxplot
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=df, width= 0.8,ax=ax,  fliersize=7)
# Out:
# <Axes: >

# %% [markdown]
# ### Insights from the plot above:-
# - Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles. This graph represents the minimum, maximum, median, first quartile and third quartile in the data set.
# - Outliers are observed in the feature 'VOLUME'.

# %%
#Displaying data using a number line
plt.figure(figsize=(30,15))
sns.lineplot(data = df)
plt.title('LINE PLOT')
plt.xlabel("DATE")
# Out:
# Text(0.5, 0, 'DATE')

# %% [markdown]
# ### Insights from the plot above:-
# - The above plot shows a line plot with the possibility of several semantic groupings. The relationship is shown for different subsets of the data using different parameters.

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.stripplot(df[column])
    plotnumber+=1
plt.tight_layout()

# %%
#EDA for the time series

# %%
df
# Out:
#                          open     close      high       low   volume
# timestamp
# 2019-09-23 08:00:00   9930.13   9930.13   9930.13   9930.13  0.00100
# 2019-09-23 09:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 10:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 11:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2019-09-23 12:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# ...                       ...       ...       ...       ...      ...
# 2024-05-08 22:00:00  61480.33  61266.23  61558.80  61134.05  1.68652
# 2024-05-08 23:00:00  61257.18  61193.08  61292.43  60909.72  1.99517
# 2024-05-09 00:00:00  61162.31  61467.90  61502.00  61137.33  7.75708
# 2024-05-09 01:00:00  61412.17  61563.08  61563.09  61412.17  0.69730
# 2024-05-09 02:00:00  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 5 columns]

# %%
df=df.reset_index()

# %%
df
# Out:
#                 timestamp      open     close      high       low   volume
# 0     2019-09-23 08:00:00   9930.13   9930.13   9930.13   9930.13  0.00100
# 1     2019-09-23 09:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2     2019-09-23 10:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 3     2019-09-23 11:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 4     2019-09-23 12:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# ...                   ...       ...       ...       ...       ...      ...
# 40550 2024-05-08 22:00:00  61480.33  61266.23  61558.80  61134.05  1.68652
# 40551 2024-05-08 23:00:00  61257.18  61193.08  61292.43  60909.72  1.99517
# 40552 2024-05-09 00:00:00  61162.31  61467.90  61502.00  61137.33  7.75708
# 40553 2024-05-09 01:00:00  61412.17  61563.08  61563.09  61412.17  0.69730
# 40554 2024-05-09 02:00:00  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 6 columns]

# %% [markdown]
# #### Checking for randomness in the dataset

# %%
import statsmodels.api as sm
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['timestamp'].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['timestamp'], lags=40, ax=ax2)

# %%
data = pd.read_csv('data.csv')
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True,cmap = "YlGnBu") #Graphical representation of data using colors to visualize the value of the matrix.
# Out:
# <Axes: >

# %%
#Vertical visualization of the boxplot
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=data, width= 0.8,ax=ax, fliersize=7)
# Out:
# <Axes: >

# %%
#Displaying data using a number line
plt.figure(figsize=(30,15))
sns.lineplot(data = data)
plt.title('LINE PLOT')
plt.xlabel("DATE")
# Out:
# Text(0.5, 0, 'DATE')

# %%
data=data.reset_index()

# %%
data.head()
# Out:
#    index   timestamp     open    close     high      low  volume
# 0      0  1569225600  9930.13  9930.13  9930.13  9930.13   0.001
# 1      1  1569229200      NaN      NaN      NaN      NaN   0.000
# 2      2  1569232800      NaN      NaN      NaN      NaN   0.000
# 3      3  1569236400      NaN      NaN      NaN      NaN   0.000
# 4      4  1569240000      NaN      NaN      NaN      NaN   0.000

# %%
data['timestamp'].plot()
plt.title("PLOT SHOWING DISTRIBUTION OF VALUES OF 'DATE'")
# Out:
# Text(0.5, 1.0, "PLOT SHOWING DISTRIBUTION OF VALUES OF 'DATE'")

# %%
data['timestamp'].describe()#description of the dataset
# Out:
# count    4.055500e+04
# mean     1.642223e+09
# std      4.214651e+07
# min      1.569226e+09
# 25%      1.605724e+09
# 50%      1.642223e+09
# 75%      1.678721e+09
# max      1.715220e+09
# Name: timestamp, dtype: float64

# %%
data["timestamp"].mean()#mean of 'DATE'
# Out:
# np.float64(1642222800.0)

# %% [markdown]
# ### Checking for randomness in the data

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(data['timestamp'].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(data['timestamp'], lags=40, ax=ax2)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from scikit-learn) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#                 timestamp      open     close      high       low   volume
# 0     2019-09-23 08:00:00   9930.13   9930.13   9930.13   9930.13  0.00100
# 1     2019-09-23 09:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 2     2019-09-23 10:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 3     2019-09-23 11:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# 4     2019-09-23 12:00:00   9930.13   9930.13   9930.13   9930.13  0.00000
# ...                   ...       ...       ...       ...       ...      ...
# 40550 2024-05-08 22:00:00  61480.33  61266.23  61558.80  61134.05  1.68652
# 40551 2024-05-08 23:00:00  61257.18  61193.08  61292.43  60909.72  1.99517
# 40552 2024-05-09 00:00:00  61162.31  61467.90  61502.00  61137.33  7.75708
# 40553 2024-05-09 01:00:00  61412.17  61563.08  61563.09  61412.17  0.69730
# 40554 2024-05-09 02:00:00  61563.26  61550.15  61563.29  61507.37  0.01823
#
# [40555 rows x 6 columns]

# %% [markdown]
# Long short-term memory (LSTM) is an artificial recurrent neural network (RNN) architecture[1] used in the field of deep learning. Unlike standard feedforward neural networks, LSTM has feedback connections. It can process not only single data points (such as images), but also entire sequences of data (such as speech or video). For example, LSTM is applicable to tasks such as unsegmented, connected handwriting recognition,[2] speech recognition[3][4] and anomaly detection in network traffic or IDSs (intrusion detection systems).
#
# A common LSTM unit is composed of a cell, an input gate, an output gate and a forget gate. The cell remembers values over arbitrary time intervals and the three gates regulate the flow of information into and out of the cell.
#
# LSTM networks are well-suited to classifying, processing and making predictions based on time series data, since there can be lags of unknown duration between important events in a time series. LSTMs were developed to deal with the vanishing gradient problem that can be encountered when training traditional RNNs. Relative insensitivity to gap length is an advantage of LSTM over RNNs, hidden Markov models and other sequence learning methods in numerous applications.
# SOURCE:Wikipedia

# %% [markdown]
# ![LSTM3-var-GRU.png](attachment:LSTM3-var-GRU.png)

# %% [markdown]
# ![1_0f8r3Vd-i4ueYND1CUrhMA.png](attachment:1_0f8r3Vd-i4ueYND1CUrhMA.png)

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089])]
# [np.float64(0.062630092050943)]
#
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089]), array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.07911385, 0.07763409,
#        0.07743722, 0.07719204, 0.0766884 , 0.06456691, 0.06144124,
#        0.0640513 , 0.06496353, 0.06541337, 0.06298994, 0.06561298,
#        0.06530563, 0.06395539, 0.06378462, 0.0630508 , 0.06278081,
#        0.06245947, 0.06046194, 0.05933366, 0.05939625, 0.0613423 ,
#        0.060243  , 0.05999739, 0.06110447, 0.0610338 , 0.06019656,
#        0.06031815, 0.06070121, 0.06035478, 0.06029089, 0.06263009])]
# [np.float64(0.062630092050943), np.float64(0.06385457266347755)]

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089])]
# [np.float64(0.062630092050943)]
#
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089]), array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.07911385, 0.07763409,
#        0.07743722, 0.07719204, 0.0766884 , 0.06456691, 0.06144124,
#        0.0640513 , 0.06496353, 0.06541337, 0.06298994, 0.06561298,
#        0.06530563, 0.06395539, 0.06378462, 0.0630508 , 0.06278081,
#        0.06245947, 0.06046194, 0.05933366, 0.05939625, 0.0613423 ,
#        0.060243  , 0.05999739, 0.06110447, 0.0610338 , 0.06019656,
#        0.06031815, 0.06070121, 0.06035478, 0.06029089, 0.06263009])]
# [np.float64(0.062630092050943), np.float64(0.06385457266347755)]

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089])]
# [np.float64(0.062630092050943)]
#
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089]), array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.07911385, 0.07763409,
#        0.07743722, 0.07719204, 0.0766884 , 0.06456691, 0.06144124,
#        0.0640513 , 0.06496353, 0.06541337, 0.06298994, 0.06561298,
#        0.06530563, 0.06395539, 0.06378462, 0.0630508 , 0.06278081,
#        0.06245947, 0.06046194, 0.05933366, 0.05939625, 0.0613423 ,
#        0.060243  , 0.05999739, 0.06110447, 0.0610338 , 0.06019656,
#        0.06031815, 0.06070121, 0.06035478, 0.06029089, 0.06263009])]
# [np.float64(0.062630092050943), np.float64(0.06385457266347755)]

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (2.6.0)
# Requirement already satisfied: filelock in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import time

# ==== 1. DEVICE CONFIG ====
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")

# ==== 2. DATA PREPARATION ====
# Graceful timestamp parsing
if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)
    print("[INFO] 'timestamp' column found and set as index.")
else:
    print("[WARN] No 'timestamp' column found. Skipping datetime parsing.")

# Use only 'close' prices
data = df[['close']].values

# ==== 3. NORMALIZATION ====
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# ==== 4. SEQUENCE CREATION ====
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(seq_length, len(data)):
        xs.append(data[i - seq_length:i])
        ys.append(data[i])
    return np.array(xs), np.array(ys)

SEQ_LEN = 60
X, y = create_sequences(scaled_data, SEQ_LEN)

# ==== 5. TRAIN/TEST SPLIT ====
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Convert to Tensors
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train, dtype=torch.float32).to(device)
X_test = torch.tensor(X_test, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test, dtype=torch.float32).to(device)

# ==== 6. MODEL DEFINITION ====
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        return self.fc(out[:, -1, :])  # last timestep

model = LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# ==== 7. TRAINING LOOP ====
EPOCHS = 80
train_losses = []

print("\n[INFO] Training started...\n")
start_time = time.time()
for epoch in range(EPOCHS):
    model.train()
    output = model(X_train)
    loss = criterion(output, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    train_losses.append(loss.item())
    print(f"Epoch [{epoch+1}/{EPOCHS}] - Loss: {loss.item():.6f}")

print("\n[INFO] Training complete.")
print(f"⏱️  Total training time: {time.time() - start_time:.2f} seconds")

# ==== 8. EVALUATION ====
model.eval()
with torch.no_grad():
    predictions = model(X_test).cpu().numpy()
    actual = y_test.cpu().numpy()

# Inverse transform
predicted_prices = scaler.inverse_transform(predictions)
actual_prices = scaler.inverse_transform(actual)

# Metrics
mse = mean_squared_error(actual_prices, predicted_prices)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actual_prices, predicted_prices)
r2 = r2_score(actual_prices, predicted_prices)

print("\nEvaluation Metrics:")
print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R²:   {r2:.4f}")

# ==== 9. PLOTTING ====
plt.figure(figsize=(14, 6))
plt.plot(actual_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.title('Bitcoin Close Price Prediction (LSTM, PyTorch)', fontsize=14)
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.title('📉 Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [INFO] Using device: cpu
# [INFO] 'timestamp' column found and set as index.
#
# [INFO] Training started...
#
# Epoch [1/80] - Loss: 0.211050
# Epoch [2/80] - Loss: 0.192363
# Epoch [3/80] - Loss: 0.174871
# Epoch [4/80] - Loss: 0.158305
# Epoch [5/80] - Loss: 0.142439
# Epoch [6/80] - Loss: 0.127106
# Epoch [7/80] - Loss: 0.112218
# Epoch [8/80] - Loss: 0.097783
# Epoch [9/80] - Loss: 0.083935
# Epoch [10/80] - Loss: 0.071013
# Epoch [11/80] - Loss: 0.059727
# Epoch [12/80] - Loss: 0.051417
# Epoch [13/80] - Loss: 0.048346
# Epoch [14/80] - Loss: 0.052727
# Epoch [15/80] - Loss: 0.060383
# Epoch [16/80] - Loss: 0.062737
# Epoch [17/80] - Loss: 0.059350
# Epoch [18/80] - Loss: 0.053870
# Epoch [19/80] - Loss: 0.049101
# Epoch [20/80] - Loss: 0.046075
# Epoch [21/80] - Loss: 0.044671
# Epoch [22/80] - Loss: 0.044354
# Epoch [23/80] - Loss: 0.044579
# Epoch [24/80] - Loss: 0.044932
# Epoch [25/80] - Loss: 0.045139
# Epoch [26/80] - Loss: 0.045043
# Epoch [27/80] - Loss: 0.044566
# Epoch [28/80] - Loss: 0.043688
# Epoch [29/80] - Loss: 0.042435
# Epoch [30/80] - Loss: 0.040863
# Epoch [31/80] - Loss: 0.039064
# Epoch [32/80] - Loss: 0.037154
# Epoch [33/80] - Loss: 0.035277
# Epoch [34/80] - Loss: 0.033585
# Epoch [35/80] - Loss: 0.032206
# Epoch [36/80] - Loss: 0.031180
# Epoch [37/80] - Loss: 0.030356
# Epoch [38/80] - Loss: 0.029347
# Epoch [39/80] - Loss: 0.027669
# Epoch [40/80] - Loss: 0.025089
# Epoch [41/80] - Loss: 0.021852
# Epoch [42/80] - Loss: 0.018466
# Epoch [43/80] - Loss: 0.015250
# Epoch [44/80] - Loss: 0.012152
# Epoch [45/80] - Loss: 0.009743
# Epoch [46/80] - Loss: 0.010160
# Epoch [47/80] - Loss: 0.008690
# Epoch [48/80] - Loss: 0.010237
# Epoch [49/80] - Loss: 0.009271
# Epoch [50/80] - Loss: 0.009222
# Epoch [51/80] - Loss: 0.009346
# Epoch [52/80] - Loss: 0.007981
# Epoch [53/80] - Loss: 0.007995
# Epoch [54/80] - Loss: 0.006950
# Epoch [55/80] - Loss: 0.005665
# Epoch [56/80] - Loss: 0.005387
# Epoch [57/80] - Loss: 0.004873
# Epoch [58/80] - Loss: 0.004035
# Epoch [59/80] - Loss: 0.003720
# Epoch [60/80] - Loss: 0.003655
# Epoch [61/80] - Loss: 0.003467
# Epoch [62/80] - Loss: 0.003214
# Epoch [63/80] - Loss: 0.003090
# Epoch [64/80] - Loss: 0.003069
# Epoch [65/80] - Loss: 0.002956
# Epoch [66/80] - Loss: 0.002721
# Epoch [67/80] - Loss: 0.002512
# Epoch [68/80] - Loss: 0.002385
# Epoch [69/80] - Loss: 0.002251
# Epoch [70/80] - Loss: 0.002048
# Epoch [71/80] - Loss: 0.001826
# Epoch [72/80] - Loss: 0.001671
# Epoch [73/80] - Loss: 0.001574
# Epoch [74/80] - Loss: 0.001454
# Epoch [75/80] - Loss: 0.001312
# Epoch [76/80] - Loss: 0.001221
# Epoch [77/80] - Loss: 0.001182
# Epoch [78/80] - Loss: 0.001133
# Epoch [79/80] - Loss: 0.001060
# Epoch [80/80] - Loss: 0.001008
#
# [INFO] Training complete.
# ⏱️  Total training time: 457.14 seconds
#
# Evaluation Metrics:
# MSE:  3826641.0000
# RMSE: 1956.1802
# MAE:  1746.3160
# R²:   0.9822
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/851232701.py:133: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) Arial.
#   plt.tight_layout()
# /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
