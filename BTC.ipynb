# %% [markdown]
# #### Exploratory data analysis

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 45.5 MB/s eta 0:00:00a 0:00:01
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ankamuday/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing the required libraries
import pandas as pd # Dataframe operations 
import numpy as np #mathematical operations
import matplotlib.pyplot as plt #graphs
import seaborn as sns #graphs
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
df=pd.read_csv('merged_fix_to_hour.csv')# reading the dataset using pandas

# %%
df.head()#Displaying the top 5 data values
# Out:
#               Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  BNB_USDT_1h_low  \
# 0  2023-04-16 00:00:00          333.0455          333.8584         332.3852
# 1  2023-04-16 01:00:00          332.3852          332.3970         330.1126
# 2  2023-04-16 02:00:00          332.1377          332.5400         332.0705
# 3  2023-04-16 03:00:00          332.2934          332.5482         331.8273
# 4  2023-04-16 04:00:00          332.2009          333.0205         331.9821
#
#    BNB_USDT_1h_close  BNB_USDT_1h_volume  BTC_USDT_1h_open  BTC_USDT_1h_high  \
# 0           332.3852            80.49008          30293.71          30316.77
# 1           332.1377           335.75052          30277.44          30277.44
# 2           332.2934            88.40229          30240.00          30278.35
# 3           332.2009            59.45825          30267.06          30268.67
# 4           333.0055           115.57138          30248.96          30307.60
#
#    BTC_USDT_1h_low  BTC_USDT_1h_close  ...  VIX_Close ^VIX  VIX_High ^VIX  \
# 0         30275.00           30277.44  ...           17.59      17.620001
# 1         30122.74           30240.00  ...           17.59      17.620001
# 2         30230.01           30267.06  ...           17.59      17.620001
# 3         30233.79           30248.96  ...           17.59      17.620001
# 4         30248.96           30302.08  ...           17.59      17.620001
#
#    VIX_Low ^VIX  VIX_Open ^VIX  VIX_Volume ^VIX  funding_rate  \
# 0         17.58          17.58              0.0        0.0001
# 1         17.58          17.58              0.0        0.0001
# 2         17.58          17.58              0.0        0.0001
# 3         17.58          17.58              0.0        0.0001
# 4         17.58          17.58              0.0        0.0001
#
#    fear_gread_index  open_interest  google_trends_buy_crypto  \
# 0              68.0      51018.926                        20
# 1              68.0      51018.926                        20
# 2              68.0      51018.926                        20
# 3              68.0      51018.926                        20
# 4              68.0      51018.926                        20
#
#    google_trends_bitcoin
# 0                     33
# 1                     33
# 2                     33
# 3                     33
# 4                     33
#
# [5 rows x 131 columns]

# %%
df.tail()#Displaying the lower 5 data values
# Out:
#                   Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  \
# 17510  2025-04-14 14:00:00            589.01            593.13
# 17511  2025-04-14 15:00:00            591.73            592.05
# 17512  2025-04-14 16:00:00            585.78            586.64
# 17513  2025-04-14 17:00:00            583.14            586.11
# 17514  2025-04-14 18:00:00            585.90            586.86
#
#        BNB_USDT_1h_low  BNB_USDT_1h_close  BNB_USDT_1h_volume  \
# 17510           588.61             591.73           468.03630
# 17511           585.46             585.78           988.02662
# 17512           583.14             583.14           688.86231
# 17513           583.14             585.90           537.27000
# 17514           585.15             586.35           216.54340
#
#        BTC_USDT_1h_open  BTC_USDT_1h_high  BTC_USDT_1h_low  BTC_USDT_1h_close  \
# 17510           84382.3           85801.6          84263.5            85423.7
# 17511           85423.7           85466.9          83720.9            84106.7
# 17512           84106.7           84679.0          83846.7            84341.3
# 17513           84341.3           84892.1          84218.2            84864.4
# 17514           84864.4           85066.8          84809.7            84916.8
#
#        ...  VIX_Close ^VIX  VIX_High ^VIX  VIX_Low ^VIX  VIX_Open ^VIX  \
# 17510  ...       37.549999          37.98     37.549999          37.98
# 17511  ...       37.549999          37.98     37.549999          37.98
# 17512  ...       37.549999          37.98     37.549999          37.98
# 17513  ...       37.549999          37.98     37.549999          37.98
# 17514  ...       37.549999          37.98     37.549999          37.98
#
#        VIX_Volume ^VIX  funding_rate  fear_gread_index  open_interest  \
# 17510              0.0      0.000052              31.0      50631.943
# 17511              0.0      0.000052              31.0      50516.250
# 17512              0.0      0.000039              31.0      49107.205
# 17513              0.0      0.000039              31.0      49182.479
# 17514              0.0      0.000039              31.0      49343.374
#
#        google_trends_buy_crypto  google_trends_bitcoin
# 17510                        22                     33
# 17511                        22                     33
# 17512                        22                     33
# 17513                        22                     33
# 17514                        22                     33
#
# [5 rows x 131 columns]

# %%
df.info() #Basic info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Columns: 131 entries, Datetime to google_trends_bitcoin
# dtypes: float64(128), int64(2), object(1)
# memory usage: 17.5+ MB

# %%
df.describe#Description of the dataset
# Out:
# <bound method NDFrame.describe of                   Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  \
# 0      2023-04-16 00:00:00          333.0455          333.8584
# 1      2023-04-16 01:00:00          332.3852          332.3970
# 2      2023-04-16 02:00:00          332.1377          332.5400
# 3      2023-04-16 03:00:00          332.2934          332.5482
# 4      2023-04-16 04:00:00          332.2009          333.0205
# ...                    ...               ...               ...
# 17510  2025-04-14 14:00:00          589.0100          593.1300
# 17511  2025-04-14 15:00:00          591.7300          592.0500
# 17512  2025-04-14 16:00:00          585.7800          586.6400
# 17513  2025-04-14 17:00:00          583.1400          586.1100
# 17514  2025-04-14 18:00:00          585.9000          586.8600
#
#        BNB_USDT_1h_low  BNB_USDT_1h_close  BNB_USDT_1h_volume  \
# 0             332.3852           332.3852            80.49008
# 1             330.1126           332.1377           335.75052
# 2             332.0705           332.2934            88.40229
# 3             331.8273           332.2009            59.45825
# 4             331.9821           333.0055           115.57138
# ...                ...                ...                 ...
# 17510         588.6100           591.7300           468.03630
# 17511         585.4600           585.7800           988.02662
# 17512         583.1400           583.1400           688.86231
# 17513         583.1400           585.9000           537.27000
# 17514         585.1500           586.3500           216.54340
#
#        BTC_USDT_1h_open  BTC_USDT_1h_high  BTC_USDT_1h_low  BTC_USDT_1h_close  \
# 0              30293.71          30316.77         30275.00           30277.44
# 1              30277.44          30277.44         30122.74           30240.00
# 2              30240.00          30278.35         30230.01           30267.06
# 3              30267.06          30268.67         30233.79           30248.96
# 4              30248.96          30307.60         30248.96           30302.08
# ...                 ...               ...              ...                ...
# 17510          84382.30          85801.60         84263.50           85423.70
# 17511          85423.70          85466.90         83720.90           84106.70
# 17512          84106.70          84679.00         83846.70           84341.30
# 17513          84341.30          84892.10         84218.20           84864.40
# 17514          84864.40          85066.80         84809.70           84916.80
#
#        ...  VIX_Close ^VIX  VIX_High ^VIX  VIX_Low ^VIX  VIX_Open ^VIX  \
# 0      ...       17.590000      17.620001     17.580000          17.58
# 1      ...       17.590000      17.620001     17.580000          17.58
# 2      ...       17.590000      17.620001     17.580000          17.58
# 3      ...       17.590000      17.620001     17.580000          17.58
# 4      ...       17.590000      17.620001     17.580000          17.58
# ...    ...             ...            ...           ...            ...
# 17510  ...       37.549999      37.980000     37.549999          37.98
# 17511  ...       37.549999      37.980000     37.549999          37.98
# 17512  ...       37.549999      37.980000     37.549999          37.98
# 17513  ...       37.549999      37.980000     37.549999          37.98
# 17514  ...       37.549999      37.980000     37.549999          37.98
#
#        VIX_Volume ^VIX  funding_rate  fear_gread_index  open_interest  \
# 0                  0.0      0.000100              68.0      51018.926
# 1                  0.0      0.000100              68.0      51018.926
# 2                  0.0      0.000100              68.0      51018.926
# 3                  0.0      0.000100              68.0      51018.926
# 4                  0.0      0.000100              68.0      51018.926
# ...                ...           ...               ...            ...
# 17510              0.0      0.000052              31.0      50631.943
# 17511              0.0      0.000052              31.0      50516.250
# 17512              0.0      0.000039              31.0      49107.205
# 17513              0.0      0.000039              31.0      49182.479
# 17514              0.0      0.000039              31.0      49343.374
#
#        google_trends_buy_crypto  google_trends_bitcoin
# 0                            20                     33
# 1                            20                     33
# 2                            20                     33
# 3                            20                     33
# 4                            20                     33
# ...                         ...                    ...
# 17510                        22                     33
# 17511                        22                     33
# 17512                        22                     33
# 17513                        22                     33
# 17514                        22                     33
#
# [17515 rows x 131 columns]>

# %%
df.duplicated().sum()#Numebr of duplicated values in the dataset
# Out:
# 0

# %%
df.isnull() #Checking for any null values in the dataset
# Out:
#        Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  BNB_USDT_1h_low  \
# 0         False             False             False            False
# 1         False             False             False            False
# 2         False             False             False            False
# 3         False             False             False            False
# 4         False             False             False            False
# ...         ...               ...               ...              ...
# 17510     False             False             False            False
# 17511     False             False             False            False
# 17512     False             False             False            False
# 17513     False             False             False            False
# 17514     False             False             False            False
#
#        BNB_USDT_1h_close  BNB_USDT_1h_volume  BTC_USDT_1h_open  \
# 0                  False               False             False
# 1                  False               False             False
# 2                  False               False             False
# 3                  False               False             False
# 4                  False               False             False
# ...                  ...                 ...               ...
# 17510              False               False             False
# 17511              False               False             False
# 17512              False               False             False
# 17513              False               False             False
# 17514              False               False             False
#
#        BTC_USDT_1h_high  BTC_USDT_1h_low  BTC_USDT_1h_close  ...  \
# 0                 False            False              False  ...
# 1                 False            False              False  ...
# 2                 False            False              False  ...
# 3                 False            False              False  ...
# 4                 False            False              False  ...
# ...                 ...              ...                ...  ...
# 17510             False            False              False  ...
# 17511             False            False              False  ...
# 17512             False            False              False  ...
# 17513             False            False              False  ...
# 17514             False            False              False  ...
#
#        VIX_Close ^VIX  VIX_High ^VIX  VIX_Low ^VIX  VIX_Open ^VIX  \
# 0               False          False         False          False
# 1               False          False         False          False
# 2               False          False         False          False
# 3               False          False         False          False
# 4               False          False         False          False
# ...               ...            ...           ...            ...
# 17510           False          False         False          False
# 17511           False          False         False          False
# 17512           False          False         False          False
# 17513           False          False         False          False
# 17514           False          False         False          False
#
#        VIX_Volume ^VIX  funding_rate  fear_gread_index  open_interest  \
# 0                False         False             False          False
# 1                False         False             False          False
# 2                False         False             False          False
# 3                False         False             False          False
# 4                False         False             False          False
# ...                ...           ...               ...            ...
# 17510            False         False             False          False
# 17511            False         False             False          False
# 17512            False         False             False          False
# 17513            False         False             False          False
# 17514            False         False             False          False
#
#        google_trends_buy_crypto  google_trends_bitcoin
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
# ...                         ...                    ...
# 17510                     False                  False
# 17511                     False                  False
# 17512                     False                  False
# 17513                     False                  False
# 17514                     False                  False
#
# [17515 rows x 131 columns]

# %%
df.isnull().sum()#Checking for the number of null values in the dataset
# Out:
# Datetime                    0
# BNB_USDT_1h_open            0
# BNB_USDT_1h_high            0
# BNB_USDT_1h_low             0
# BNB_USDT_1h_close           0
#                            ..
# funding_rate                0
# fear_gread_index            0
# open_interest               0
# google_trends_buy_crypto    0
# google_trends_bitcoin       0
# Length: 131, dtype: int64

# %%
df.columns #Columns present in the dataset
# Out:
# Index(['Datetime', 'BNB_USDT_1h_open', 'BNB_USDT_1h_high', 'BNB_USDT_1h_low',
#        'BNB_USDT_1h_close', 'BNB_USDT_1h_volume', 'BTC_USDT_1h_open',
#        'BTC_USDT_1h_high', 'BTC_USDT_1h_low', 'BTC_USDT_1h_close',
#        ...
#        'VIX_Close ^VIX', 'VIX_High ^VIX', 'VIX_Low ^VIX', 'VIX_Open ^VIX',
#        'VIX_Volume ^VIX', 'funding_rate', 'fear_gread_index', 'open_interest',
#        'google_trends_buy_crypto', 'google_trends_bitcoin'],
#       dtype='object', length=131)

# %%
df.shape #(number of rows, number of columns)
# Out:
# (17515, 131)

# %%
df.head() #displaying top 5 values
# Out:
#               Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  BNB_USDT_1h_low  \
# 0  2023-04-16 00:00:00          333.0455          333.8584         332.3852
# 1  2023-04-16 01:00:00          332.3852          332.3970         330.1126
# 2  2023-04-16 02:00:00          332.1377          332.5400         332.0705
# 3  2023-04-16 03:00:00          332.2934          332.5482         331.8273
# 4  2023-04-16 04:00:00          332.2009          333.0205         331.9821
#
#    BNB_USDT_1h_close  BNB_USDT_1h_volume  BTC_USDT_1h_open  BTC_USDT_1h_high  \
# 0           332.3852            80.49008          30293.71          30316.77
# 1           332.1377           335.75052          30277.44          30277.44
# 2           332.2934            88.40229          30240.00          30278.35
# 3           332.2009            59.45825          30267.06          30268.67
# 4           333.0055           115.57138          30248.96          30307.60
#
#    BTC_USDT_1h_low  BTC_USDT_1h_close  ...  VIX_Close ^VIX  VIX_High ^VIX  \
# 0         30275.00           30277.44  ...           17.59      17.620001
# 1         30122.74           30240.00  ...           17.59      17.620001
# 2         30230.01           30267.06  ...           17.59      17.620001
# 3         30233.79           30248.96  ...           17.59      17.620001
# 4         30248.96           30302.08  ...           17.59      17.620001
#
#    VIX_Low ^VIX  VIX_Open ^VIX  VIX_Volume ^VIX  funding_rate  \
# 0         17.58          17.58              0.0        0.0001
# 1         17.58          17.58              0.0        0.0001
# 2         17.58          17.58              0.0        0.0001
# 3         17.58          17.58              0.0        0.0001
# 4         17.58          17.58              0.0        0.0001
#
#    fear_gread_index  open_interest  google_trends_buy_crypto  \
# 0              68.0      51018.926                        20
# 1              68.0      51018.926                        20
# 2              68.0      51018.926                        20
# 3              68.0      51018.926                        20
# 4              68.0      51018.926                        20
#
#    google_trends_bitcoin
# 0                     33
# 1                     33
# 2                     33
# 3                     33
# 4                     33
#
# [5 rows x 131 columns]

# %% [markdown]
# #### It was observed that the Datatype of DATE column is object, so let us convert it into datetime.

# %%
import pandas as pd

# Assuming your DataFrame is already loaded as df

# 1) Convert your 'Datetime' column to pandas datetime objects
df['timestamp'] = pd.to_datetime(df['Datetime'])  # No 'unit' needed

# 2) Make 'timestamp' the index so ffill respects time order
df.set_index('timestamp', inplace=True)

# 3) Forward-fill missing values in all columns
df.fillna(method='ffill', inplace=True)

# (Optional) If you only want to forward-fill price columns:
# price_cols = ['open', 'high', 'low', 'close']
# df[price_cols] = df[price_cols].fillna(method='ffill')

print(df.head())
# Out:
#                                 Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  \
# timestamp
# 2023-04-16 00:00:00  2023-04-16 00:00:00          333.0455          333.8584
# 2023-04-16 01:00:00  2023-04-16 01:00:00          332.3852          332.3970
# 2023-04-16 02:00:00  2023-04-16 02:00:00          332.1377          332.5400
# 2023-04-16 03:00:00  2023-04-16 03:00:00          332.2934          332.5482
# 2023-04-16 04:00:00  2023-04-16 04:00:00          332.2009          333.0205
#
#                      BNB_USDT_1h_low  BNB_USDT_1h_close  BNB_USDT_1h_volume  \
# timestamp
# 2023-04-16 00:00:00         332.3852           332.3852            80.49008
# 2023-04-16 01:00:00         330.1126           332.1377           335.75052
# 2023-04-16 02:00:00         332.0705           332.2934            88.40229
# 2023-04-16 03:00:00         331.8273           332.2009            59.45825
# 2023-04-16 04:00:00         331.9821           333.0055           115.57138
#
#                      BTC_USDT_1h_open  BTC_USDT_1h_high  BTC_USDT_1h_low  \
# timestamp
# 2023-04-16 00:00:00          30293.71          30316.77         30275.00
# 2023-04-16 01:00:00          30277.44          30277.44         30122.74
# 2023-04-16 02:00:00          30240.00          30278.35         30230.01
# 2023-04-16 03:00:00          30267.06          30268.67         30233.79
# 2023-04-16 04:00:00          30248.96          30307.60         30248.96
#
#                      BTC_USDT_1h_close  ...  VIX_Close ^VIX  VIX_High ^VIX  \
# timestamp                               ...
# 2023-04-16 00:00:00           30277.44  ...           17.59      17.620001
# 2023-04-16 01:00:00           30240.00  ...           17.59      17.620001
# 2023-04-16 02:00:00           30267.06  ...           17.59      17.620001
# 2023-04-16 03:00:00           30248.96  ...           17.59      17.620001
# 2023-04-16 04:00:00           30302.08  ...           17.59      17.620001
#
#                      VIX_Low ^VIX  VIX_Open ^VIX  VIX_Volume ^VIX  \
# timestamp
# 2023-04-16 00:00:00         17.58          17.58              0.0
# 2023-04-16 01:00:00         17.58          17.58              0.0
# 2023-04-16 02:00:00         17.58          17.58              0.0
# 2023-04-16 03:00:00         17.58          17.58              0.0
# 2023-04-16 04:00:00         17.58          17.58              0.0
#
#                      funding_rate  fear_gread_index  open_interest  \
# timestamp
# 2023-04-16 00:00:00        0.0001              68.0      51018.926
# 2023-04-16 01:00:00        0.0001              68.0      51018.926
# 2023-04-16 02:00:00        0.0001              68.0      51018.926
# 2023-04-16 03:00:00        0.0001              68.0      51018.926
# 2023-04-16 04:00:00        0.0001              68.0      51018.926
#
#                      google_trends_buy_crypto  google_trends_bitcoin
# timestamp
# 2023-04-16 00:00:00                        20                     33
# 2023-04-16 01:00:00                        20                     33
# 2023-04-16 02:00:00                        20                     33
# 2023-04-16 03:00:00                        20                     33
# 2023-04-16 04:00:00                        20                     33
#
# [5 rows x 131 columns]
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_38170/1179191851.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.info()# successfully converted the column to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17515 entries, 2023-04-16 00:00:00 to 2025-04-14 18:00:00
# Columns: 131 entries, Datetime to google_trends_bitcoin
# dtypes: float64(128), int64(2), object(1)
# memory usage: 17.6+ MB

# %%
df #8857 rows × 7 columns in our dataset
# Out:
#                                 Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  \
# timestamp
# 2023-04-16 00:00:00  2023-04-16 00:00:00          333.0455          333.8584
# 2023-04-16 01:00:00  2023-04-16 01:00:00          332.3852          332.3970
# 2023-04-16 02:00:00  2023-04-16 02:00:00          332.1377          332.5400
# 2023-04-16 03:00:00  2023-04-16 03:00:00          332.2934          332.5482
# 2023-04-16 04:00:00  2023-04-16 04:00:00          332.2009          333.0205
# ...                                  ...               ...               ...
# 2025-04-14 14:00:00  2025-04-14 14:00:00          589.0100          593.1300
# 2025-04-14 15:00:00  2025-04-14 15:00:00          591.7300          592.0500
# 2025-04-14 16:00:00  2025-04-14 16:00:00          585.7800          586.6400
# 2025-04-14 17:00:00  2025-04-14 17:00:00          583.1400          586.1100
# 2025-04-14 18:00:00  2025-04-14 18:00:00          585.9000          586.8600
#
#                      BNB_USDT_1h_low  BNB_USDT_1h_close  BNB_USDT_1h_volume  \
# timestamp
# 2023-04-16 02:00:00                        20                     33
# 2023-04-16 03:00:00                        20                     33
# 2023-04-16 04:00:00                        20                     33
# ...                                       ...                    ...
# 2025-04-14 14:00:00                        22                     33
# 2025-04-14 15:00:00                        22                     33
# 2025-04-14 16:00:00                        22                     33
# 2025-04-14 17:00:00                        22                     33
# 2025-04-14 18:00:00                        22                     33
#
# [17515 rows x 131 columns]

# %%
# #Plotting the distribution plots for all the features
# plt.figure(figsize=(20,25))
# plotnumber=1
# for column in df:
#     if plotnumber<=7:
#         ax=plt.subplot(3,3,plotnumber)
#         sns.distplot(df[column])
#         plt.xlabel(column, fontsize=20)
#     plotnumber+=1
# plt.show()

# %%
# sns.pairplot(data=df) # relation between each and every variable present in Pandas DataFrame.

# %% [markdown]
# ### Insights from the plot above:-
# - Above plot shows pairwise relationships in a dataset.
# - Most of the plots are showing linear relationship while others are not showing any specific relationship

# %%
# sns.heatmap(df.corr(),annot=True,cmap = "YlGnBu") #Graphical representation of data using colors to visualize the value of the matrix.

# %% [markdown]
# #### Let us check for any outliers

# %%
#plotting boxplots for all the features
plt.figure(figsize=(20,25))
plotnumber=1
for column in df:
    if plotnumber<=7:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Vertical visualization of the boxplot
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=df, width= 0.8,ax=ax,  fliersize=7)
# Out:
# <Axes: >

# %% [markdown]
# ### Insights from the plot above:-
# - Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles. This graph represents the minimum, maximum, median, first quartile and third quartile in the data set.
# - Outliers are observed in the feature 'VOLUME'.

# %%
#Displaying data using a number line
plt.figure(figsize=(30,15))
sns.lineplot(data = df)
plt.title('LINE PLOT')
plt.xlabel("DATE")
# Out:
# Text(0.5, 0, 'DATE')

# %% [markdown]
# ### Insights from the plot above:-
# - The above plot shows a line plot with the possibility of several semantic groupings. The relationship is shown for different subsets of the data using different parameters.

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.stripplot(df[column])
    plotnumber+=1
plt.tight_layout()

# %%
#EDA for the time series

# %%
df
# Out:
#                                 Datetime  BNB_USDT_1h_open  BNB_USDT_1h_high  \
# timestamp
# 2023-04-16 00:00:00  2023-04-16 00:00:00          333.0455          333.8584
# 2023-04-16 01:00:00  2023-04-16 01:00:00          332.3852          332.3970
# 2023-04-16 02:00:00  2023-04-16 02:00:00          332.1377          332.5400
# 2023-04-16 03:00:00  2023-04-16 03:00:00          332.2934          332.5482
# 2023-04-16 04:00:00  2023-04-16 04:00:00          332.2009          333.0205
# ...                                  ...               ...               ...
# 2025-04-14 14:00:00  2025-04-14 14:00:00          589.0100          593.1300
# 2025-04-14 15:00:00  2025-04-14 15:00:00          591.7300          592.0500
# 2025-04-14 16:00:00  2025-04-14 16:00:00          585.7800          586.6400
# 3                59.45825          30267.06          30268.67  ...
# 4               115.57138          30248.96          30307.60  ...
# ...                   ...               ...               ...  ...
# 17510           468.03630          84382.30          85801.60  ...
# 17511           988.02662          85423.70          85466.90  ...
# 17512           688.86231          84106.70          84679.00  ...
# 17513           537.27000          84341.30          84892.10  ...
# 17514           216.54340          84864.40          85066.80  ...
#
#        VIX_Close ^VIX  VIX_High ^VIX  VIX_Low ^VIX  VIX_Open ^VIX  \
# 0           17.590000      17.620001     17.580000          17.58
# 1           17.590000      17.620001     17.580000          17.58
# 2           17.590000      17.620001     17.580000          17.58
# 3           17.590000      17.620001     17.580000          17.58
# 4           17.590000      17.620001     17.580000          17.58
# ...               ...            ...           ...            ...
# 17510       37.549999      37.980000     37.549999          37.98
# 17511       37.549999      37.980000     37.549999          37.98
# 17512       37.549999      37.980000     37.549999          37.98
# 17513       37.549999      37.980000     37.549999          37.98
# 17514       37.549999      37.980000     37.549999          37.98
#
#        VIX_Volume ^VIX  funding_rate  fear_gread_index  open_interest  \
# 0                  0.0      0.000100              68.0      51018.926
# 1                  0.0      0.000100              68.0      51018.926
# 2                  0.0      0.000100              68.0      51018.926
# 3                  0.0      0.000100              68.0      51018.926
# 4                  0.0      0.000100              68.0      51018.926
# ...                ...           ...               ...            ...
# 17510              0.0      0.000052              31.0      50631.943
# 17511              0.0      0.000052              31.0      50516.250
# 17512              0.0      0.000039              31.0      49107.205
# 17513              0.0      0.000039              31.0      49182.479
# 17514              0.0      0.000039              31.0      49343.374
#
#        google_trends_buy_crypto  google_trends_bitcoin
# 0                            20                     33
# 1                            20                     33
# 2                            20                     33
# 3                            20                     33
# 4                            20                     33
# ...                         ...                    ...
# 17510                        22                     33
# 17511                        22                     33
# 17512                        22                     33
# 17513                        22                     33
# 17514                        22                     33
#
# [17515 rows x 133 columns]

# %% [markdown]
# #### Checking for randomness in the dataset

# %%
import statsmodels.api as sm
# %matplotlib inline
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['timestamp'].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['timestamp'], lags=40, ax=ax2)

# %%
data = pd.read_csv('data.csv')
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True,cmap = "YlGnBu") #Graphical representation of data using colors to visualize the value of the matrix.
# Out:
# <Axes: >

# %%
#Vertical visualization of the boxplot
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=data, width= 0.8,ax=ax, fliersize=7)
# Out:
# <Axes: >

# %%
#Displaying data using a number line
plt.figure(figsize=(30,15))
sns.lineplot(data = data)
plt.title('LINE PLOT')
plt.xlabel("DATE")
# Out:
# Text(0.5, 0, 'DATE')

# %%
data=data.reset_index()

# %%
data.head()
# Out:
#    index   timestamp     open    close     high      low  volume
# 0      0  1569225600  9930.13  9930.13  9930.13  9930.13   0.001
# 1      1  1569229200      NaN      NaN      NaN      NaN   0.000
# 2      2  1569232800      NaN      NaN      NaN      NaN   0.000
# 3      3  1569236400      NaN      NaN      NaN      NaN   0.000
# 4      4  1569240000      NaN      NaN      NaN      NaN   0.000

# %%
data['timestamp'].plot()
plt.title("PLOT SHOWING DISTRIBUTION OF VALUES OF 'DATE'")
# Out:
# Text(0.5, 1.0, "PLOT SHOWING DISTRIBUTION OF VALUES OF 'DATE'")

# %%
data['timestamp'].describe()#description of the dataset
# Out:
# count    4.055500e+04
# mean     1.642223e+09
# std      4.214651e+07
# min      1.569226e+09
# 25%      1.605724e+09
# 50%      1.642223e+09
# 75%      1.678721e+09
# max      1.715220e+09
# Name: timestamp, dtype: float64

# %%
data["timestamp"].mean()#mean of 'DATE'
# Out:
# 1642222800.0

# %% [markdown]
# ### Checking for randomness in the data

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(data['timestamp'].values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(data['timestamp'], lags=40, ax=ax2)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#        index           timestamp             Datetime  BNB_USDT_1h_open  \
# 0          0 2023-04-16 00:00:00  2023-04-16 00:00:00          333.0455
# 1          1 2023-04-16 01:00:00  2023-04-16 01:00:00          332.3852
# 2          2 2023-04-16 02:00:00  2023-04-16 02:00:00          332.1377
# 3          3 2023-04-16 03:00:00  2023-04-16 03:00:00          332.2934
# 4          4 2023-04-16 04:00:00  2023-04-16 04:00:00          332.2009
# ...      ...                 ...                  ...               ...
# 17510  17510 2025-04-14 14:00:00  2025-04-14 14:00:00          589.0100
# 17511  17511 2025-04-14 15:00:00  2025-04-14 15:00:00          591.7300
# 17512  17512 2025-04-14 16:00:00  2025-04-14 16:00:00          585.7800
# 17513  17513 2025-04-14 17:00:00  2025-04-14 17:00:00          583.1400
# 17514  17514 2025-04-14 18:00:00  2025-04-14 18:00:00          585.9000
#
#        BNB_USDT_1h_high  BNB_USDT_1h_low  BNB_USDT_1h_close  \
# 0              333.8584         332.3852           332.3852
# 1              332.3970         330.1126           332.1377
# 2              332.5400         332.0705           332.2934
# 3              332.5482         331.8273           332.2009
# 4              333.0205         331.9821           333.0055
# ...                 ...              ...                ...
# 17510          593.1300         588.6100           591.7300
# 17511          592.0500         585.4600           585.7800
# 17512          586.6400         583.1400           583.1400
# 17513          586.1100         583.1400           585.9000
# 17514          586.8600         585.1500           586.3500
#
#        BNB_USDT_1h_volume  BTC_USDT_1h_open  BTC_USDT_1h_high  ...  \
# 0                80.49008          30293.71          30316.77  ...
# 1               335.75052          30277.44          30277.44  ...
# 2                88.40229          30240.00          30278.35  ...
# 3                59.45825          30267.06          30268.67  ...
# 4               115.57138          30248.96          30307.60  ...
# ...                   ...               ...               ...  ...
# 17510           468.03630          84382.30          85801.60  ...
# 17511           988.02662          85423.70          85466.90  ...
# 17512           688.86231          84106.70          84679.00  ...
# 17513           537.27000          84341.30          84892.10  ...
# 17514           216.54340          84864.40          85066.80  ...
#
#        VIX_Close ^VIX  VIX_High ^VIX  VIX_Low ^VIX  VIX_Open ^VIX  \
# 0           17.590000      17.620001     17.580000          17.58
# 1           17.590000      17.620001     17.580000          17.58
# 2           17.590000      17.620001     17.580000          17.58
# 3           17.590000      17.620001     17.580000          17.58
# 4           17.590000      17.620001     17.580000          17.58
# ...               ...            ...           ...            ...
# 17510       37.549999      37.980000     37.549999          37.98
# 17511       37.549999      37.980000     37.549999          37.98
# 17512       37.549999      37.980000     37.549999          37.98
# 17513       37.549999      37.980000     37.549999          37.98
# 17514       37.549999      37.980000     37.549999          37.98
#
#        VIX_Volume ^VIX  funding_rate  fear_gread_index  open_interest  \
# 0                  0.0      0.000100              68.0      51018.926
# 1                  0.0      0.000100              68.0      51018.926
# 2                  0.0      0.000100              68.0      51018.926
# 3                  0.0      0.000100              68.0      51018.926
# 4                  0.0      0.000100              68.0      51018.926
# ...                ...           ...               ...            ...
# 17510              0.0      0.000052              31.0      50631.943
# 17511              0.0      0.000052              31.0      50516.250
# 17512              0.0      0.000039              31.0      49107.205
# 17513              0.0      0.000039              31.0      49182.479
# 17514              0.0      0.000039              31.0      49343.374
#
#        google_trends_buy_crypto  google_trends_bitcoin
# 0                            20                     33
# 1                            20                     33
# 2                            20                     33
# 3                            20                     33
# 4                            20                     33
# ...                         ...                    ...
# 17510                        22                     33
# 17511                        22                     33
# 17512                        22                     33
# 17513                        22                     33
# 17514                        22                     33
#
# [17515 rows x 133 columns]

# %% [markdown]
# Long short-term memory (LSTM) is an artificial recurrent neural network (RNN) architecture[1] used in the field of deep learning. Unlike standard feedforward neural networks, LSTM has feedback connections. It can process not only single data points (such as images), but also entire sequences of data (such as speech or video). For example, LSTM is applicable to tasks such as unsegmented, connected handwriting recognition,[2] speech recognition[3][4] and anomaly detection in network traffic or IDSs (intrusion detection systems).
#
# A common LSTM unit is composed of a cell, an input gate, an output gate and a forget gate. The cell remembers values over arbitrary time intervals and the three gates regulate the flow of information into and out of the cell.
#
# LSTM networks are well-suited to classifying, processing and making predictions based on time series data, since there can be lags of unknown duration between important events in a time series. LSTMs were developed to deal with the vanishing gradient problem that can be encountered when training traditional RNNs. Relative insensitivity to gap length is an advantage of LSTM over RNNs, hidden Markov models and other sequence learning methods in numerous applications.
# SOURCE:Wikipedia

# %% [markdown]
# ![LSTM3-var-GRU.png](attachment:LSTM3-var-GRU.png)

# %% [markdown]
# ![1_0f8r3Vd-i4ueYND1CUrhMA.png](attachment:1_0f8r3Vd-i4ueYND1CUrhMA.png)

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089])]
# [np.float64(0.062630092050943)]
#
# [array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0
.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.07911385,
#        0.07763409, 0.07743722, 0.07719204, 0.0766884 , 0.06456691,
#        0.06144124, 0.0640513 , 0.06496353, 0.06541337, 0.06298994,
#        0.06561298, 0.06530563, 0.06395539, 0.06378462, 0.0630508 ,
#        0.06278081, 0.06245947, 0.06046194, 0.05933366, 0.05939625,
#        0.0613423 , 0.060243  , 0.05999739, 0.06110447, 0.0610338 ,
#        0.06019656, 0.06031815, 0.06070121, 0.06035478, 0.06029089]), array([0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.08333247, 0.08333247,
#        0.08333247, 0.08333247, 0.08333247, 0.07911385, 0.07763409,
#        0.07743722, 0.07719204, 0.0766884 , 0.06456691, 0.06144124,
#        0.0640513 , 0.06496353, 0.06541337, 0.06298994, 0.06561298,
#        0.06530563, 0.06395539, 0.06378462, 0.0630508 , 0.06278081,
#        0.06245947, 0.06046194, 0.05933366, 0.05939625, 0.0613423 ,
#        0.060243  , 0.05999739, 0.06110447, 0.0610338 , 0.06019656,
#        0.06031815, 0.06070121, 0.06035478, 0.06029089, 0.06263009])]
# [np.float64(0.062630092050943), np.float64(0.06385457266347755)]

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (2.6.0)
# Requirement already satisfied: filelock in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import time

# ==== 1. DEVICE CONFIG ====
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")

# ==== 2. DATA PREPARATION ====
# Graceful timestamp parsing
if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)
    print("[INFO] 'timestamp' column found and set as index.")
else:
    print("[WARN] No 'timestamp' column found. Skipping datetime parsing.")

# Use only 'close' prices
data = df[['close']].values

# ==== 3. NORMALIZATION ====
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# ==== 4. SEQUENCE CREATION ====
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(seq_length, len(data)):
        xs.append(data[i - seq_length:i])
        ys.append(data[i])
    return np.array(xs), np.array(ys)

SEQ_LEN = 60
X, y = create_sequences(scaled_data, SEQ_LEN)

# ==== 5. TRAIN/TEST SPLIT ====
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Convert to Tensors
X_train = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train, dtype=torch.float32).to(device)
X_test = torch.tensor(X_test, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test, dtype=torch.float32).to(device)

# ==== 6. MODEL DEFINITION ====
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        return self.fc(out[:, -1, :])  # last timestep

model = LSTM().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# ==== 7. TRAINING LOOP ====
EPOCHS = 80
train_losses = []

print("\n[INFO] Training started...\n")
start_time = time.time()
for epoch in range(EPOCHS):
    model.train()
    output = model(X_train)
    loss = criterion(output, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    train_losses.append(loss.item())
    print(f"Epoch [{epoch+1}/{EPOCHS}] - Loss: {loss.item():.6f}")

print("\n[INFO] Training complete.")
print(f"⏱️  Total training time: {time.time() - start_time:.2f} seconds")

# ==== 8. EVALUATION ====
model.eval()
with torch.no_grad():
    predictions = model(X_test).cpu().numpy()
    actual = y_test.cpu().numpy()

# Inverse transform
predicted_prices = scaler.inverse_transform(predictions)
actual_prices = scaler.inverse_transform(actual)

# Metrics
mse = mean_squared_error(actual_prices, predicted_prices)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actual_prices, predicted_prices)
r2 = r2_score(actual_prices, predicted_prices)

print("\nEvaluation Metrics:")
print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R²:   {r2:.4f}")

# ==== 9. PLOTTING ====
plt.figure(figsize=(14, 6))
plt.plot(actual_prices, label='Actual Price')
plt.plot(predicted_prices, label='Predicted Price')
plt.title('Bitcoin Close Price Prediction (LSTM, PyTorch)', fontsize=14)
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Training Loss')
plt.title('📉 Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [INFO] Using device: cpu
# [INFO] 'timestamp' column found and set as index.
#
# [INFO] Training started...
#
# Epoch [1/80] - Loss: 0.211050
# Epoch [2/80] - Loss: 0.192363
# Epoch [3/80] - Loss: 0.174871
# Epoch [4/80] - Loss: 0.158305
# Epoch [5/80] - Loss: 0.142439
# Epoch [6/80] - Loss: 0.127106
# Epoch [7/80] - Loss: 0.112218
# Epoch [8/80] - Loss: 0.097783
# Epoch [9/80] - Loss: 0.083935
# Epoch [10/80] - Loss: 0.071013
# Epoch [11/80] - Loss: 0.059727
# Epoch [12/80] - Loss: 0.051417
# Epoch [13/80] - Loss: 0.048346
# Epoch [14/80] - Loss: 0.052727
# Epoch [15/80] - Loss: 0.060383
# Epoch [16/80] - Loss: 0.062737
# Epoch [17/80] - Loss: 0.059350
# Epoch [18/80] - Loss: 0.053870
# Epoch [19/80] - Loss: 0.049101
# Epoch [20/80] - Loss: 0.046075
# Epoch [21/80] - Loss: 0.044671
# Epoch [22/80] - Loss: 0.044354
# Epoch [23/80] - Loss: 0.044579
# Epoch [24/80] - Loss: 0.044932
# Epoch [25/80] - Loss: 0.045139
# Epoch [26/80] - Loss: 0.045043
# Epoch [27/80] - Loss: 0.044566
# Epoch [28/80] - Loss: 0.043688
# Epoch [29/80] - Loss: 0.042435
# Epoch [30/80] - Loss: 0.040863
# Epoch [31/80] - Loss: 0.039064
# Epoch [32/80] - Loss: 0.037154
# Epoch [33/80] - Loss: 0.035277
# Epoch [34/80] - Loss: 0.033585
# Epoch [35/80] - Loss: 0.032206
# Epoch [36/80] - Loss: 0.031180
# Epoch [37/80] - Loss: 0.030356
# Epoch [38/80] - Loss: 0.029347
# Epoch [39/80] - Loss: 0.027669
# Epoch [40/80] - Loss: 0.025089
# Epoch [41/80] - Loss: 0.021852
# Epoch [42/80] - Loss: 0.018466
# Epoch [43/80] - Loss: 0.015250
# Epoch [44/80] - Loss: 0.012152
# Epoch [45/80] - Loss: 0.009743
# Epoch [46/80] - Loss: 0.010160
# Epoch [47/80] - Loss: 0.008690
# Epoch [48/80] - Loss: 0.010237
# Epoch [49/80] - Loss: 0.009271
# Epoch [50/80] - Loss: 0.009222
# Epoch [51/80] - Loss: 0.009346
# Epoch [52/80] - Loss: 0.007981
# Epoch [53/80] - Loss: 0.007995
# Epoch [54/80] - Loss: 0.006950
# Epoch [55/80] - Loss: 0.005665
# Epoch [56/80] - Loss: 0.005387
# Epoch [57/80] - Loss: 0.004873
# Epoch [58/80] - Loss: 0.004035
# Epoch [59/80] - Loss: 0.003720
# Epoch [60/80] - Loss: 0.003655
# Epoch [61/80] - Loss: 0.003467
# Epoch [62/80] - Loss: 0.003214
# Epoch [63/80] - Loss: 0.003090
# Epoch [64/80] - Loss: 0.003069
# Epoch [65/80] - Loss: 0.002956
# Epoch [66/80] - Loss: 0.002721
# Epoch [67/80] - Loss: 0.002512
# Epoch [68/80] - Loss: 0.002385
# Epoch [69/80] - Loss: 0.002251
# Epoch [70/80] - Loss: 0.002048
# Epoch [71/80] - Loss: 0.001826
# Epoch [72/80] - Loss: 0.001671
# Epoch [73/80] - Loss: 0.001574
# Epoch [74/80] - Loss: 0.001454
# Epoch [75/80] - Loss: 0.001312
# Epoch [76/80] - Loss: 0.001221
# Epoch [77/80] - Loss: 0.001182
# Epoch [78/80] - Loss: 0.001133
# Epoch [79/80] - Loss: 0.001060
# Epoch [80/80] - Loss: 0.001008
#
# [INFO] Training complete.
# ⏱️  Total training time: 457.14 seconds
#
# Evaluation Metrics:
# MSE:  3826641.0000
# RMSE: 1956.1802
# MAE:  1746.3160
# R²:   0.9822
# /var/folders/qh/b47g2xl114n1xyw41cd7_gvh0000gn/T/ipykernel_54601/851232701.py:133: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) Arial.
#   plt.tight_layout()
# /opt/homebrew/Cellar/jupyterlab/4.4.0/libexec/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# --- Step 1: Load and clean data ---
df = pd.read_csv('merged_fix_to_hour.csv')

# Drop non-numeric columns (e.g., 'Datetime')
df = df.select_dtypes(include=[np.number])

# Define target column
target_col = 'BNB_USDT_1h_close'

# %%
# --- Step 2: Normalize all columns ---
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)

# %%
# --- Step 3: Create sequences ---
def create_sequences(data, target, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data.iloc[i - seq_len:i].values)
        y.append(data.iloc[i][target])
    return np.array(X), np.array(y)

SEQ_LEN = 60
X, y = create_sequences(scaled_df, target_col, SEQ_LEN)

# --- Step 4: Train-test split ---
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X.shape[1], X.shape[2])),
    Dropout(0.2),
    LSTM(64),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/20
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0142 - val_loss: 0.0021
# Epoch 2/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0017 - val_loss: 5.7867e-04
# Epoch 3/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0013 - val_loss: 3.3980e-04
# Epoch 4/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 5/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 8.9911e-04 - val_loss: 3.5746e-04
# Epoch 6/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.9333e-04 - val_loss: 4.3157e-04
# Epoch 7/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.3286e-04 - val_loss: 3.7640e-04
# Epoch 8/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 7.4366e-04 - val_loss: 7.0702e-04
# Epoch 9/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 6.5547e-04 - val_loss: 0.0014
# Epoch 10/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 6.2039e-04 - val_loss: 9.1527e-04
# Epoch 11/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 6.8237e-04 - val_loss: 0.0017
# Epoch 12/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.5205e-04 - val_loss: 0.0017
# Epoch 13/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.2326e-04 - val_loss: 0.0023
# Epoch 14/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.4456e-04 - val_loss: 7.1454e-04
# Epoch 15/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.3668e-04 - val_loss: 4.3687e-04
# Epoch 16/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.1113e-04 - val_loss: 0.0011
# Epoch 17/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.2034e-04 - val_loss: 0.0016
# Epoch 18/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 5.1119e-04 - val_loss: 5.6975e-04
# Epoch 19/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.7540e-04 - val_loss: 0.0019
# Epoch 20/20
# 393/393 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 4.8179e-04 - val_loss: 9.1932e-04

# %%
# Predict
y_pred = model.predict(X_test)

# Inverse scale prediction and actual values for the 'BNB_USDT_1h_close' column
target_index = df.columns.get_loc(target_col)
target_scaler = MinMaxScaler()
target_scaler.min_, target_scaler.scale_ = scaler.min_[target_index], scaler.scale_[target_index]
y_pred_inv = target_scaler.inverse_transform(y_pred)
y_test_inv = target_scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual BNB Close')
plt.plot(y_pred_inv, label='Predicted BNB Close')
plt.title('BNB Close Price Prediction with LSTM')
plt.legend()
plt.show()
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# # Backtesting

# %%
predictions = []
actuals = []

# Walk-forward prediction
for i in range(len(X_test)):
    X_input = X_test[i:i+1]  # shape: (1, seq_len, features)
    pred = model.predict(X_input, verbose=0)
    
    predictions.append(pred[0][0])
    actuals.append(y_test[i])

# %%
# Inverse scale
predictions_inv = target_scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
actuals_inv = target_scaler.inverse_transform(np.array(actuals).reshape(-1, 1))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(actuals_inv, label='Actual')
plt.plot(predictions_inv, label='Predicted')
plt.title('LSTM Backtesting on BNB Close Price')
plt.xlabel('Time Steps')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(actuals_inv, predictions_inv)
mae = mean_absolute_error(actuals_inv, predictions_inv)

print(f'MSE: {mse:.4f}')
print(f'MAE: {mae:.4f}')
# Out:
# MSE: 594.4314
# MAE: 20.3170

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(actuals_inv, predictions_inv)
mae = mean_absolute_error(actuals_inv, predictions_inv)

print(f'MSE: {mse:.4f}')
print(f'MAE: {mae:.4f}')
# Out:
# MSE: 594.4314
# MAE: 20.3170

# %%
# Save the entire model (architecture + weights + optimizer)
model.save('bnb_lstm_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('bnb_lstm_model.h5')

y_pred = model.predict(X_test)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
y_pred
# Out:
# array([[0.7127943],
#        [0.712526 ],
#        [0.7135713],
#        ...,
#        [0.592152 ],
#        [0.5931316],
#        [0.5943953]], dtype=float32)

# %%
import joblib

# Save
joblib.dump(scaler, 'bnb_scaler.pkl')

# Load later
scaler = joblib.load('bnb_scaler.pkl')
